# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("E:\\sukamal sir machine learning\\Machine-learning-master\\house.csv")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df["bedrooms"].hist()
plt.show()

# %%
df["bedrooms"].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
bedroom_type=df["bedrooms"].unique()

# %%
bedroom_type
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
bedroom_count=df["bedrooms"].value_counts()

# %%
bedroom_count
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 8       13
# 0       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.title("bedroom_type vs bedroom_count")
plt.xlabel("bedroom_type")
plt.ylabel("bedroom_count")
plt.bar(bedroom_type,bedroom_count)
plt.show()

# %%
df["bedrooms"].value_counts().plot(kind="bar")
plt.xticks(rotation=30)
plt.show()

# %%
plt.figure(figsize=(8,8))
df["bedrooms"].value_counts().plot.pie()
plt.show()

# %%
plt.figure(figsize=(6,6))
df["bedrooms"].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
df["bedrooms"].nunique()
# Out:
# 13

# %%
a=np.full((13),0.1)

# %%
plt.figure(figsize=(6,6))
df["bedrooms"].value_counts().plot.pie(autopct="%1.1f%%",explode=a)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(df["bedrooms"],df["price"])
plt.xlabel("bedroom")
plt.ylabel("price")
plt.show()

# %%
cor=df.corr()

# %% [markdown]
# cor

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
mean_bedroom=df["bedrooms"].mean()
median_bedroom=df["bedrooms"].median()
plt.figure(figsize=(6,6))
plt.hist(df["bedrooms"])
plt.axvline(mean_bedroom,color="red")
plt.axvline(median_bedroom,color="green")
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(df["floors"],df["view"])
plt.xlabel("floors")
plt.ylabel("view")
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(df["floors"],df["price"])
plt.xlabel("floors")
plt.ylabel("price")
plt.show()

# %%
cor["price"]
# Out:
# id              -0.016762
# price            1.000000
# bedrooms         0.308350
# bathrooms        0.525138
# sqft_living      0.702035
# sqft_lot         0.089661
# floors           0.256794
# waterfront       0.266369
# view             0.397293
# condition        0.036362
# grade            0.667434
# sqft_above       0.605567
# sqft_basement    0.323816
# yr_built         0.054012
# yr_renovated     0.126434
# zipcode         -0.053203
# lat              0.307003
# long             0.021626
# sqft_living15    0.585379
# sqft_lot15       0.082447
# Name: price, dtype: float64

# %%
mean_bedroom=df["bedrooms"].mean()
median_bedroom=df["bedrooms"].median()
plt.figure(figsize=(6,6))
sns.distplot(df["bedrooms"])
plt.axvline(mean_bedroom,color="red")
plt.axvline(median_bedroom,color="green")
plt.show()

# %%
mean_bedroom=df["price"].mean()
median_bedroom=df["price"].median()
plt.figure(figsize=(6,6))
sns.distplot(df["price"])
plt.axvline(mean_bedroom,color="red")
plt.axvline(median_bedroom,color="green")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(data=df,x="bedrooms")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(data=df,y="bathrooms")
plt.show()

# %%
df["bathrooms"].value_counts()
# Out:
# 2.50    5380
# 1.00    3852
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1446
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      72
# 4.75      23
# 5.00      21
# 5.25      13
# 0.00      10
# 5.50      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 8.00       2
# 6.25       2
# 6.50       2
# 6.75       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64

# %%
df["grade"].value_counts()
# Out:
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      90
# 4       29
# 13      13
# 3        3
# 1        1
# Name: grade, dtype: int64

# %%
plt.figure(figsize=(9,9))
sns.countplot(data=df,x="bedrooms",hue="grade")
plt.show()

# %%
cor=df.corr()

# %%
cor
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
sns.heatmap(cor,annot=True)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(cor,annot=True,cmap="viridis")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data=df,x="bedrooms",y="sqft_living")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x="bedrooms",y="bathrooms",hue="price")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.boxplot(data=df,x="yr_built")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data=df,x="yr_built",y="price")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.boxplot(data=df,x="bedrooms",y="bathrooms")
plt.show()

# %%
fig,axes=plt.subplots(2,2,figsize=(15,15))
for i in range(2):
    for j in range(2):
        sns.scatterplot(data=df,x="yr_built",y="price",ax=axes[i,j])
        plt.show()

# %%
fig,axes=plt.subplots(2,2,figsize=(15,15))
for i in range(2):   # Pick a first col
    for j in range(2):
        sns.boxplot(data=df,x="bedrooms",y="bathrooms",ax=axes[i,j]) 
      
        plt.show()
