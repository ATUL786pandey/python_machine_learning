# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("E:\\sukamal sir machine learning\Machine-learning-master\\bank.csv")

# %%
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
df
# Out:
#        age            job   marital  education default  balance housing loan  \
# 0       59         admin.   married  secondary      no     2343     yes   no
# 1       56         admin.   married  secondary      no       45      no   no
# 2       41     technician   married  secondary      no     1270     yes   no
# 3       55       services   married  secondary      no     2476     yes   no
# 4       54         admin.   married   tertiary      no      184      no   no
# 5       42     management    single   tertiary      no        0     yes  yes
# 6       56     management   married   tertiary      no      830     yes  yes
# 7       60        retired  divorced  secondary      no      545     yes   no
# 8       37     technician   married  secondary      no        1     yes   no
# 9       28       services    single  secondary      no     5090     yes   no
# 10      38         admin.    single  secondary      no      100     yes   no
# ...

# %%
df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %%
df["balance"].value_counts()
# Out:
#  0        774
#  1         39
#  3         35
#  2         34
#  4         29
#  5         27
#  19        20
#  8         19
#  62        18
#  67        17
#  61        17
#  21        17
#  46        17
#  6         17
#  22        16
#  205       16
#  154       16
#  16        16
#  294       16
#  23        15
#  108       15
#  292       15
#  131       15
#  30        15
#  136       15
#  102       15
#  127       15
#  223       15
#  25        14
#  94        14
#          ...
#  4497       1
# -994        1
# -405        1
#  2458       1
#  4513       1
#  2466       1
#  3031       1
#  11219      1
# -978        1
#  4545       1
# -970        1
#  2506       1
#  966        1
#  958        1
# -477        1
#  4577       1
#  2530       1
# -493        1
# -938        1
# -509        1
#  5028       1
#  2570       1
# -930        1
#  2578       1
#  531        1
#  4641       1
#  2975       1
#  918        1
#  2959       1
#  7561       1
# ...

# %%
df["balance"].nunique()
# Out:
# 3805

# %%
plt.figure(figsize=(6,6))
plt.hist(df["balance"],bins=10)
plt.show()

# %%
mean_balance=df["balance"].mean()
median_balance=df["balance"].median()
plt.figure(figsize=(7,7))
plt.hist(df["balance"])
plt.axvline(mean_balance,color="orange")
plt.axvline(median_balance,color="green")
plt.show()

# %%
balane_type=df["balance"].unique()

# %%
balance=df["balance"].hist()
balance

# %%
df
# Out:
#        age            job   marital  education default  balance housing loan  \
# 0       59         admin.   married  secondary      no     2343     yes   no
# 1       56         admin.   married  secondary      no       45      no   no
# 2       41     technician   married  secondary      no     1270     yes   no
# 3       55       services   married  secondary      no     2476     yes   no
# 4       54         admin.   married   tertiary      no      184      no   no
# 5       42     management    single   tertiary      no        0     yes  yes
# 6       56     management   married   tertiary      no      830     yes  yes
# 7       60        retired  divorced  secondary      no      545     yes   no
# 8       37     technician   married  secondary      no        1     yes   no
# 9       28       services    single  secondary      no     5090     yes   no
# 10      38         admin.    single  secondary      no      100     yes   no
# ...

# %%
df["job"].unique()
# Out:
# array(['admin.', 'technician', 'services', 'management', 'retired',
#        'blue-collar', 'unemployed', 'entrepreneur', 'housemaid',
#        'unknown', 'self-employed', 'student'], dtype=object)

# %%
job_type=df["job"].unique()

# %%
job_type
# Out:
# array(['admin.', 'technician', 'services', 'management', 'retired',
#        'blue-collar', 'unemployed', 'entrepreneur', 'housemaid',
#        'unknown', 'self-employed', 'student'], dtype=object)

# %%
job_count=df["job"].value_counts()

# %%
job_count
# Out:
# management       2566
# blue-collar      1944
# technician       1823
# admin.           1334
# services          923
# retired           778
# self-employed     405
# student           360
# unemployed        357
# entrepreneur      328
# housemaid         274
# unknown            70
# Name: job, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.title("job_type vs job_count")
plt.xlabel("job_type")
plt.ylabel("job_count")

plt.bar(job_type,job_count)
plt.show()

# %%
df["job"].value_counts().plot(kind="bar")# we have to plot bar with this
plt.show()

# %%
df["job"].value_counts().plot.pie()
plt.show()

# %%
plt.figure(figsize=(8,8))
df["job"].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
jobs=df["job"].nunique()
jobs
# Out:
# 12

# %%
a=np.full((12),0.2)

# %%
plt.figure(figsize=(6,6))
df["job"].value_counts().plot.pie(autopct="%1.1f%%",explode=a)
plt.show()

# %%
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
plt.figure(figsize=(15,15))
df["balance"].value_counts().plot(kind="bar")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.scatter(df["job"],df["balance"])
plt.xlabel("job")
plt.ylabel("balance")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.scatter(df["balance"],df["duration"])
plt.xlabel("balance")
plt.ylabel("duration")
plt.show()

# %%
cor=df.corr()

# %%
cor
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.112300 -0.000762  0.000189 -0.005278  0.002774  0.020169
# balance   0.112300  1.000000  0.010467  0.022436 -0.013894  0.017411  0.030805
# day      -0.000762  0.010467  1.000000 -0.018511  0.137007 -0.077232 -0.058981
# duration  0.000189  0.022436 -0.018511  1.000000 -0.041557 -0.027392 -0.026716
# campaign -0.005278 -0.013894  0.137007 -0.041557  1.000000 -0.102726 -0.049699
# pdays     0.002774  0.017411 -0.077232 -0.027392 -0.102726  1.000000  0.507272
# previous  0.020169  0.030805 -0.058981 -0.026716 -0.049699  0.507272  1.000000

# %%
plt.figure(figsize=(8,8))
plt.scatter(df["balance"],df["day"])
plt.xlabel("balance")
plt.ylabel("days")
plt.show()

# %%
cor["pdays"]
# Out:
# age         0.002774
# balance     0.017411
# day        -0.077232
# duration   -0.027392
# campaign   -0.102726
# pdays       1.000000
# previous    0.507272
# Name: pdays, dtype: float64

# %%
cor["balance"]
# Out:
# age         0.112300
# balance     1.000000
# day         0.010467
# duration    0.022436
# campaign   -0.013894
# pdays       0.017411
# previous    0.030805
# Name: balance, dtype: float64
